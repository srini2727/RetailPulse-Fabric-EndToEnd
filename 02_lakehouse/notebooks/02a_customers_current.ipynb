# %%
spark.sql("""
CREATE OR REPLACE TABLE silver_customers_current AS
SELECT
    customer_id,
    country,
    segment,
    effective_start_ts,
    effective_end_ts,
    is_current
FROM silver_customers_scd2
WHERE is_current = true
""")

print("✅ silver_customers_current created")
